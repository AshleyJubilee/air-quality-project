# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import hvplot.pandas
import pandas as pd
import requests
import scipy.stats as st
import os 
import csv

# %%
#Read File
CSV_PATH = os.path.join("aqi_data.csv")
aqi_df = pd.read_csv(CSV_PATH)
aqi_df.head()
# Out:
#               country              city  aqi_value aqi_category  co_aqi_value  \
# 0  Russian Federation        Praskoveya         51     Moderate             1
# 1              Brazil  Presidente Dutra         41         Good             1
# 2               Italy   Priolo Gargallo         66     Moderate             1
# 3              Poland         Przasnysz         34         Good             1
# 4              France          Punaauia         22         Good             0
#
#   co_aqi_category  ozone_aqi_value ozone_aqi_category  no2_aqi_value  \
# 0            Good               36               Good              0
# 1            Good                5               Good              1
# 2            Good               39               Good              2
# 3            Good               34               Good              0
# 4            Good               22               Good              0
#
#   no2_aqi_category  pm2.5_aqi_value pm2.5_aqi_category        Lat         Lon
# ...

# %%
haz_df =aqi_df.loc[(aqi_df['aqi_category'] == 'Hazardous')]
haz_df.head()
# Out:
#           country          city  aqi_value aqi_category  co_aqi_value  \
# 180         India    Govindgarh        307    Hazardous             1
# 276      Pakistan  Bahawalnagar        500    Hazardous             1
# 277  South Africa       Balfour        380    Hazardous            31
# 417         India      Phillaur        444    Hazardous             2
# 439         India         Salon        303    Hazardous             1
#
#     co_aqi_category  ozone_aqi_value              ozone_aqi_category  \
# 180            Good               45                            Good
# 276            Good               38                            Good
# 277            Good                1                            Good
# 417            Good              111  Unhealthy for Sensitive Groups
# 439            Good               48                            Good
#
#      no2_aqi_value no2_aqi_category  pm2.5_aqi_value pm2.5_aqi_category  \
# ...

# %%
Unhealthy_df =aqi_df.loc[(aqi_df['aqi_category'] == 'Unhealthy')]
Unhealthy_df.head()
# Out:
#      country       city  aqi_value aqi_category  co_aqi_value co_aqi_category  \
# 12     India     Radaur        158    Unhealthy             3            Good
# 13  Pakistan     Radhan        158    Unhealthy             1            Good
# 16     India     Rajgir        154    Unhealthy             3            Good
# 19     India  Phulabani        161    Unhealthy             2            Good
# 23     China    Pingyin        150    Unhealthy             3            Good
#
#     ozone_aqi_value              ozone_aqi_category  no2_aqi_value  \
# 12              139  Unhealthy for Sensitive Groups              1
# 13               50                            Good              1
# 16              100  Unhealthy for Sensitive Groups              2
# 19               71                        Moderate              0
# 23               95                        Moderate              6
#
#    no2_aqi_category  pm2.5_aqi_value pm2.5_aqi_category        Lat         Lon
# ...

# %%
good_df =aqi_df.loc[(aqi_df['aqi_category'] == 'Good')]
good_df.head()
# Out:
#         country              city  aqi_value aqi_category  co_aqi_value  \
# 1        Brazil  Presidente Dutra         41         Good             1
# 3        Poland         Przasnysz         34         Good             1
# 4        France          Punaauia         22         Good             0
# 11  Netherlands            Raalte         41         Good             1
# 20       Poland         Piaseczno         28         Good             1
#
#    co_aqi_category  ozone_aqi_value ozone_aqi_category  no2_aqi_value  \
# 1             Good                5               Good              1
# 3             Good               34               Good              0
# 4             Good               22               Good              0
# 11            Good               24               Good              6
# 20            Good               28               Good              2
#
#    no2_aqi_category  pm2.5_aqi_value pm2.5_aqi_category        Lat         Lon
# ...

# %%
Moderate_df =aqi_df.loc[(aqi_df['aqi_category'] == 'Moderate')]
Unhealthy_Sensitive_Groups_df.head()
# Out:
# Empty DataFrame
# Columns: [country, city, aqi_value, aqi_category, co_aqi_value, co_aqi_category, ozone_aqi_value, ozone_aqi_category, no2_aqi_value, no2_aqi_category, pm2.5_aqi_value, pm2.5_aqi_category, Lat, Lon]
# Index: []

# %%
# %%capture --no-display
# Plots All AQI Cities Mapped 
# Configure the map plot  
AQI_Total =clean_df.hvplot.points(
    "Lon",
    "Lat",
#     size="aqi_value",
#     c="pm2.5_aqi_category",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 700,
    scale = 10,
    hover_cols=["country", "city","aqi_category"])

# Display the map
AQI_Total
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lon,Lat]   (country,city,aqi_category)

# %%
# %%capture --no-display
#Plots Hazardous AQI Countries in the World
# Configure the map plot
API_HAZ =haz_df.hvplot.points(
    "Lon",
    "Lat",
    size="aqi_value",
    geo = True,
    c="pm2.5_aqi_category",
    tiles = "OSM",
    frame_width = 800,
    frame_height = 700,
    scale = 0.5,
    hover_cols=["country", "city","aqi_value","pm2.5_aqi_category"])
# Display the map
API_HAZ
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lon,Lat]   (pm2.5_aqi_category,aqi_value,country,city)

# %%
# %%capture --no-display
#Plots vunhealthy AQI Countries in the World
# Configure the map plot
API_very_unhealthy =v_unhealthy_df.hvplot.points(
    "Lon",
    "Lat",
#     size="aqi_value",
    geo = True,
#     c="pm2.5_aqi_category",
    tiles = "OSM",
    frame_width = 800,
    frame_height = 700,
    scale = 0.5,
    hover_cols=["country", "city","aqi_value","pm2.5_aqi_category"])
# Display the map
API_very_unhealthy
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lon,Lat]   (country,city,aqi_value,pm2.5_aqi_category)

# %%
# %%capture --no-display
#Plots unhealthy AQI Countries in the World
# Configure the map plot
API_unhealthy =Unhealthy_df.hvplot.points(
    "Lon",
    "Lat",
#     size="aqi_value",
    geo = True,
#     c="pm2.5_aqi_category",
    tiles = "OSM",
    frame_width = 800,
    frame_height = 700,
    scale = 0.5,
    hover_cols=["country", "city","aqi_value","pm2.5_aqi_category"])
# Display the map
API_unhealthy
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lon,Lat]   (country,city,aqi_value,pm2.5_aqi_category)

# %%
# %%capture --no-display
#Plots unhealthy AQI Countries in the World
# Configure the map plot
API_good =good_df.hvplot.points(
    "Lon",
    "Lat",
#     size="aqi_value",
    geo = True,
#     c="pm2.5_aqi_category",
    tiles = "OSM",
    frame_width = 800,
    frame_height = 700,
    scale = 0.5,
    hover_cols=["country", "city","aqi_value","pm2.5_aqi_category"])
# Display the map
API_good
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lon,Lat]   (country,city,aqi_value,pm2.5_aqi_category)
