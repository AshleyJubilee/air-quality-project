# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
air_path = "Untitled Folder 1/aqi_data.csv"

# %%
air_path = pd.read_csv(air_path)

# %%
air_path.head()
# Out:
#               country              city  aqi_value aqi_category  co_aqi_value  \
# 0  Russian Federation        Praskoveya         51     Moderate             1
# 1              Brazil  Presidente Dutra         41         Good             1
# 2               Italy   Priolo Gargallo         66     Moderate             1
# 3              Poland         Przasnysz         34         Good             1
# 4              France          Punaauia         22         Good             0
#
#   co_aqi_category  ozone_aqi_value ozone_aqi_category  no2_aqi_value  \
# 0            Good               36               Good              0
# 1            Good                5               Good              1
# 2            Good               39               Good              2
# 3            Good               34               Good              0
# 4            Good               22               Good              0
#
#   no2_aqi_category  pm2.5_aqi_value pm2.5_aqi_category        Lat         Lon
# ...

# %%
df = pd.DataFrame(air_path)

# %%
name = df['country'].head(15)
price = df['co_aqi_value'].head(15)
fig = plt.figure(figsize =(40,10))
plt.bar(name[0:20], price[0:20])
plt.xlabel('country')
plt.show()

# %%
name = df['country'].head(30)
price = df['ozone_aqi_value'].head(30)
fig = plt.figure(figsize =(40, 10))
plt.bar(name[0:20], price[0:20])
plt.show()

# %%
name = df['country'].head(30)
price = df['aqi_value'].head(30)
fig = plt.figure(figsize =(40, 10))
plt.bar(name[0:20], price[0:20])
plt.show()

# %%
name = df['country'].head(30)
price = df['no2_aqi_value'].head(30)
fig = plt.figure(figsize =(40, 10))
plt.bar(name[0:20], price[0:20])
plt.show()

# %%
name = df['country'].head(30)
price = df['pm2.5_aqi_value'].head(30)
fig = plt.figure(figsize =(40, 10))
plt.bar(name[0:20], price[0:20])
plt.show()

# %%
name = df['aqi_value'].head(30)
price = df['ozone_aqi_value'].head(30)
fig = plt.figure(figsize =(40, 10))
plt.bar(name[0:20], price[0:20])

plt.show()
